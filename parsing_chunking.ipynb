# %%
import nltk
import spacy

from nltk.tokenize import word_tokenize
from nltk.chunk import RegexpParser

# Download required NLTK resources
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('averaged_perceptron_tagger_eng', quiet=True)

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

print("Parsing and Chunking setup completed!")
# Out:
# Parsing and Chunking setup completed!

# %%
import nltk
import spacy
from nltk.tokenize import word_tokenize
from nltk.chunk import RegexpParser

# Download required resources
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('averaged_perceptron_tagger_eng', quiet=True)

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

print("Parsing and Chunking setup completed!")

sentence = "Alok is developing an intelligent chatbot using Python."

# ---------- RegEx Chunking ----------
print("========== REGEX CHUNKING ==========")

words = word_tokenize(sentence)
pos_tags = nltk.pos_tag(words)

# Grammar for Noun Phrase
grammar = r"NP: {<DT>?<JJ>*<NN.*>+}"

chunk_parser = RegexpParser(grammar)
chunk_tree = chunk_parser.parse(pos_tags)

print("\nPOS Tagged Sentence:")
print(pos_tags)

print("\nChunking Result:")
chunk_tree.pretty_print()

# ---------- spaCy Parsing ----------
print("\n========== SPACY DEPENDENCY PARSING ==========")

doc = nlp(sentence)

print("\nWord\tPOS\tDependency\tHead")
print("-" * 45)

for token in doc:
    print(f"{token.text}\t{token.pos_}\t{token.dep_}\t\t{token.head.text}")
# Out:
# Parsing and Chunking setup completed!
# ========== REGEX CHUNKING ==========
#
# POS Tagged Sentence:
# [('Alok', 'NNP'), ('is', 'VBZ'), ('developing', 'VBG'), ('an', 'DT'), ('intelligent', 'NN'), ('chatbot', 'NN'), ('using', 'VBG'), ('Python', 'NNP'), ('.', '.')]
#
# Chunking Result:
#                                        S
#    ____________________________________|_________________________________________
#   |          |            |      |     NP                NP                      NP
#   |          |            |      |     |        _________|____________           |
# is/VBZ developing/VBG using/VBG ./. Alok/NNP an/DT intelligent/NN chatbot/NN Python/NNP
#
#
# ========== SPACY DEPENDENCY PARSING ==========
#
# Word	POS	Dependency	Head
# ---------------------------------------------
# Alok	PROPN	nsubj		developing
# is	AUX	aux		developing
# developing	VERB	ROOT		developing
# an	DET	det		chatbot
# intelligent	ADJ	amod		chatbot
# chatbot	NOUN	dobj		developing
# ...
